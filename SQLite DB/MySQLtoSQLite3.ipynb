# %% [markdown]
# ## DATA MIGRATION FROM MySQL TO SQLITE3

# %%
# Import Libarary
import sqlite3
import mysql.connector as mysqlConnection
from pandas.io import sql

# %%
# Establish Connection
sqliteConn = sqlite3.connect("testdb.db")

# MySQL Connection
mysqlConn = mysqlConnection.Connect(host="localhost", user="root", passwd="", database="beneficiary_db")

# %%
# Declare Cursor
sqliteCursor = sqliteConn.cursor()

# %%
# Excute MySQL Query, Fetch from MySQL
df = sql.read_sql("SELECT * FROM beneficiaries LIMIT 5", mysqlConn)
df
# Out:
# c:\users\adinath nikam\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    index                                id  active     created_at  \
# 0      0  8a8b803a7cbdbb65017cbe19cb4f0770       1  1635276933967
# 1      1  8a8b803a7cbdbb65017cbe19ce1b0774       1  1635276934683
# 2      2  8a8b803a7cbdbb65017cbe19d0e60778       1  1635276935398
# 3      3  8a8b803a7cbdbb65017cbe19d3b0077c       1  1635276936111
# 4      4  8a8b803a7cbdbb65017cbe19d6790780       1  1635276936825
#
#                              created_by  deleted last_modified_by  \
# 0  089f5038-e0b5-4f6b-8401-9f9217a2341c        0             None
# 1  089f5038-e0b5-4f6b-8401-9f9217a2341c        0             None
# ...

# %%
# Load to SQLite Database
df.to_sql(name="testtbl", con=sqliteConn)
# Out:
# 5

# %%
# Fetch Single Column from SQLite Database
fetchedCursor = sqliteCursor.execute("SELECT * FROM testtbl;")
for i in fetchedCursor:
    print(i[15])
# Out:
# None
# None
# None
# None
# None

# %%
# Fetch from SQLite Database
df = sql.read_sql("SELECT * FROM testtbl", sqliteConn)
df
# Out:
#    level_0  index                                id  active     created_at  \
# 0        0      0  8a8b803a7cbdbb65017cbe19cb4f0770       1  1635276933967
# 1        1      1  8a8b803a7cbdbb65017cbe19ce1b0774       1  1635276934683
# 2        2      2  8a8b803a7cbdbb65017cbe19d0e60778       1  1635276935398
# 3        3      3  8a8b803a7cbdbb65017cbe19d3b0077c       1  1635276936111
# 4        4      4  8a8b803a7cbdbb65017cbe19d6790780       1  1635276936825
#
#                              created_by  deleted last_modified_by  \
# 0  089f5038-e0b5-4f6b-8401-9f9217a2341c        0             None
# 1  089f5038-e0b5-4f6b-8401-9f9217a2341c        0             None
# 2  089f5038-e0b5-4f6b-8401-9f9217a2341c        0             None
# 3  089f5038-e0b5-4f6b-8401-9f9217a2341c        0             None
# 4  089f5038-e0b5-4f6b-8401-9f9217a2341c        0             None
#
#      modified_at   age  ... highest_educational_passout_year is_migrant  \
# ...
